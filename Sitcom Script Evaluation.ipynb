# %% [markdown]
# # 🎬🎯 Sitcom Script Evaluation
#
# This notebook evaluates pilot episodes of a sitcom generated using two different approaches: a baseline model and a ReAct-based multi-agent system. Each episode consists of 20 scenes, divided into 5 blocks of 4 scenes. The evaluations are performed by a language model (LLM), which scores each block using a structured rubric covering **Coherence**, **Relevance**, **Interestingness**, **Humor**, and **Overall Quality**. For context, the LLM is given both the current scene block and the preceding block’s scene descriptions. Results are compiled and compared across episodes to assess which generation method produces stronger sitcom writing.

# %% [markdown]
# ## Mounting Drive and Appending System

# %%
# Import necessary modules
from google.colab import drive
import sys

# Mount Google Drive to access files stored in your Google Drive
drive.mount('/content/drive')

# NOTE: Update the paths below to match the location of your project files in Google Drive.
# Replace with your own directory if different.

# Add the main 'utils' directory to Python's module search path
# This allows you to import custom utility modules from this folder
sys.path.append("/content/drive/MyDrive/Spring 2025/Gen AI with LLM/Project/utils")

# Add the 'agents' subdirectory to the module search path
# Useful if you have agent-specific Python scripts you want to import
sys.path.append("/content/drive/MyDrive/Spring 2025/Gen AI with LLM/Project/utils/agents")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Importing Libraries and Packages

# %%
# Import utility functions for processing and evaluating sitcom scripts
from text_utils import (
    get_episode_concept,
    get_scene_description_block,
    extract_and_partition_scenes
)

from eval_utils import (
    evaluate_scene_block,
    evaluate_episode_blocks,
    extract_evaluation_scores
)

# %%
# Import core libraries for API access, environment interaction, and data analysis
from openai import OpenAI
from google.colab import userdata
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ### 🔑 Initializing the OpenAI API Client

# %%
api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

# %% [markdown]
# ### Reading Title, Episode Outline, and Baseline and ReAct Scripts
#
# Below, we read in the title, episode outline, and baseline and ReAct scripts for the five episodes.

# %%
# Set base directory
base_path = "/content/drive/MyDrive/Spring 2025/Gen AI with LLM/Project/pilot episode data"

# Load and assign variables dynamically
for i in range(1, 6):
    folder = f"pilot episode {i}"
    folder_path = os.path.join(base_path, folder)

    try:
        # Sitcom title
        with open(os.path.join(folder_path, f"sitcom_title_{i}.txt"), "r") as f:
            globals()[f"sitcom_title_{i}"] = f.read().strip()

        # Episode outline
        with open(os.path.join(folder_path, f"episode_outline_{i}.txt"), "r") as f:
            globals()[f"episode_outline_{i}"] = f.read()

        # Baseline pilot script
        with open(os.path.join(folder_path, f"baseline_pilot_ep_scrpt_{i}.txt"), "r") as f:
            globals()[f"baseline_pilot_ep_scrpt_{i}"] = f.read()

        # ReAct pilot script
        with open(os.path.join(folder_path, f"react_pilot_ep_scrpt_{i}.txt"), "r") as f:
            globals()[f"react_pilot_ep_scrpt_{i}"] = f.read()

    except FileNotFoundError as e:
        print(f"⚠️ Missing file in episode {i}: {e}")

# %% [markdown]
# ### Displaying First 200 Characters for Episode Title, Outline, Baseline and ReActScripts

# %%
for i in range(1, 6):
    print(f"\n{'='*30} EPISODE {i} {'='*30}\n")

    # Sitcom title
    print(f"Sitcom Title {i}:\n{globals()[f'sitcom_title_{i}']}\n")

    # Episode outline preview
    print(f"Episode Outline {i} (first 200 chars):\n{globals()[f'episode_outline_{i}'][:200]}\n")

    # Baseline script preview
    print(f"{'-'*10} BASELINE SCRIPT (first 200 chars) {'-'*10}")
    print(globals()[f'baseline_pilot_ep_scrpt_{i}'][:200], "\n")

    # ReAct script preview
    print(f"{'-'*10} REACT SCRIPT (first 200 chars) {'-'*10}")
    print(globals()[f'react_pilot_ep_scrpt_{i}'][:200], "\n")
# Out:
# ============================== EPISODE 1 ==============================
#
# Sitcom Title 1:
# Unlocked Potential
#
# Episode Outline 1 (first 200 chars):
# Episode Concept: Frankie's estranged daughter, Isabella, moves to NYC and unexpectedly becomes the manager of his locksmith shop; their quirky dynamic is tested when Frankie's parole officer, Gary, st
#
# ---------- BASELINE SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. FRANKIE'S LOCKSMITH SHOP - MORNING
#
# FRANKIE, a slightly grizzled but spry locksmith with a twinkle in his eye, flips the sign on his shop door from "CLOSED" to "OPEN."
#
#
# ---------- REACT SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. FRANKIE'S LOCKSMITH SHOP - DAY
#
# FRANKIE, a middle-aged man with a big personality and a bigger toolbox, flips the sign on the door from “CLOSED” to “OPEN.”
#
# FRANKIE:
# (c
#
#
# ============================== EPISODE 2 ==============================
#
# Sitcom Title 2:
# Key Changes
#
# Episode Outline 2 (first 200 chars):
# Episode Concept: In the pilot episode, "A Fresh Start", ex-con Jimmy takes over his late uncle's locksmith business and his estranged daughter, Lisa, shows up to help, while their quirky parole office
#
# ---------- BASELINE SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. EARL'S LOCKSMITH SHOP - DAY
#
# [Camera pans over an old-fashioned locksmith shop, filled with keys hanging on hooks, an array of locks on the counter, and an old, worn, y
#
# ---------- REACT SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. EARL'S LOCKSMITH SHOP - DAY
#
# JIMMY, a spry man in his early 30s, is hunched over a workbench. He's engaged in a battle of wits with a particularly stubborn lock. He wea
#
#
# ============================== EPISODE 3 ==============================
#
# Sitcom Title 3:
# Second Lock
#
# Episode Outline 3 (first 200 chars):
# **Episode Concept:** Jimmy's estranged daughter, Sophie, unexpectedly shows up at his locksmith shop, the same day he receives a mysterious package from his past. Meanwhile, his parole officer, Earl,
#
# ---------- BASELINE SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. JIMMY'S LOCKSMITH SHOP - DAY
#
# JIMMY, a middle-aged man with a quirky sense of humor, is seen unlocking the door of his locksmith shop. He fumbles with a large key ring
#
# ---------- REACT SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. JIMMY'S LOCKSMITH SHOP - MORNING
#
# JIMMY, mid 40s, opens the door to his shop, a jumble of keys jingling from his belt. He flips the sign from CLOSED to OPEN. He's weari
#
#
# ============================== EPISODE 4 ==============================
#
# Sitcom Title 4:
# Keyed Up
#
# Episode Outline 4 (first 200 chars):
# Episode Concept: Jimmy, a former convict, opens a locksmith shop in NYC and is unexpectedly joined by his business school dropout daughter, Samantha. Their first day of running the business together i
#
# ---------- BASELINE SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. JIMMY'S LOCKSMITH SHOP - MORNING
#
# JIMMY, a burly ex-con with a heart of gold, is carefully arranging various lock sets on a display shelf. His large hands struggle with
#
# ---------- REACT SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. JIMMY'S LOCKSMITH SHOP - MORNING
#
# JIMMY, a burly man in his 50s with a twinkle in his eye, is meticulously arranging a display of ornate keychains near the front window
#
#
# ============================== EPISODE 5 ==============================
#
# Sitcom Title 5:
# Unlocked Potential
#
# Episode Outline 5 (first 200 chars):
# Episode Concept: In the pilot episode, Frankie is released from prison and discovers he has inherited his uncle's locksmith shop; meanwhile, he meets his quirky parole officer, Len, and reconnects wit
#
# ---------- BASELINE SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. PRISON GATES - DAY
#
# FRANKIE, early 50s, a bit worn but with a twinkle in his eye, steps through the prison gates, suitcase in hand.
#
# FRANKIE
# (squinting against the sunl
#
# ---------- REACT SCRIPT (first 200 chars) ----------
# ### Scene 1 ###
# # Scene 1
#
# INT. PRISON GATE - DAY
#
# FRANKIE, mid-40s, but looks older due to his rugged features and prison tattoos, steps out of the gate with a duffle bag. He looks around nervously,

# %% [markdown]
# ### Extracting Episode Concepts
# Below, we extract the episode concept for each of the five episodes.
# Since both the Baseline and ReAct versions share the same concept, a single concept per episode is extracted. These concepts will be used as context during scene block evaluation.

# %%
# Extract episode concepts for episodes 1 through 5
for i in range(1, 6):
    outline = globals()[f"episode_outline_{i}"]
    concept = get_episode_concept(outline)
    globals()[f"episode_concept_{i}"] = concept

# Print to verify
for i in range(1, 6):
    print(f"\nEpisode {i} Concept:\n{globals()[f'episode_concept_{i}']}")
# Out:
# Episode 1 Concept:
# Frankie's estranged daughter, Isabella, moves to NYC and unexpectedly becomes the manager of his locksmith shop; their quirky dynamic is tested when Frankie's parole officer, Gary, stirs up trouble.
#
# Episode 2 Concept:
# In the pilot episode, "A Fresh Start", ex-con Jimmy takes over his late uncle's locksmith business and his estranged daughter, Lisa, shows up to help, while their quirky parole officer, Stanley, introduces himself with a Broadway-inspired entrance.
#
# Episode 3 Concept:
# ** Jimmy's estranged daughter, Sophie, unexpectedly shows up at his locksmith shop, the same day he receives a mysterious package from his past. Meanwhile, his parole officer, Earl, is dealing with his own issues, leading to a day full of chaos, laughter, and heart.
#
# Episode 4 Concept:
# Jimmy, a former convict, opens a locksmith shop in NYC and is unexpectedly joined by his business school dropout daughter, Samantha. Their first day of running the business together is filled with challenges, bonding moments, and unexpected visits from Terry, Jimmy's eccentric parole officer.
#
# Episode 5 Concept:
# In the pilot episode, Frankie is released from prison and discovers he has inherited his uncle's locksmith shop; meanwhile, he meets his quirky parole officer, Len, and reconnects with his estranged daughter, Ellie.

# %% [markdown]
# ### Scene Description Blocks
#
# A potential limitation of evaluating every 4 scenes in isolation is that, for the first block (Scenes 1–4), the language model lacks prior narrative context beyond the episode concept.To improve coherence evaluations, we provide the model with scene descriptions from the previous 4 scenes as additional context—starting from Block 2 onward.
#
# Below, we extract 5 blocks of 4 scene descriptions for each of the 5 episode outlines, resulting in a total of 25 blocks.

# %%
# Shared scene descriptions for Episodes 1–5 (used by both Baseline and ReAct)
scene_description_blocks = {}

for i in range(1, 6):  # Episodes 1 to 5
    blocks = get_scene_description_block(globals()[f"episode_outline_{i}"], block_size=4)
    scene_description_blocks[i] = {
        f"scene_block_{j+1}": block
        for j, block in enumerate(blocks)
    }

# %% [markdown]
# ### Extracting Scenes
# We extract 5 blocks of 4 scenes for each episode.
# This process is performed for both the Baseline and ReAct versions across 5 episodes, resulting in a total of 50 scene blocks.

# %%
# Store all baseline and ReAct scene blocks by episode number
baseline_script_blocks = {}
react_script_blocks = {}

for i in range(1, 6):
    # ----- Baseline -----
    baseline_script = globals()[f"baseline_pilot_ep_scrpt_{i}"]
    baseline_blocks = extract_and_partition_scenes(baseline_script, block_size=4)

    baseline_script_blocks[i] = {
        f"scene_block_{j+1}": block for j, block in enumerate(baseline_blocks.values())
    }
    for key, block in baseline_script_blocks[i].items():
        globals()[f"{key}_ep{i}_baseline"] = block

    # ----- ReAct -----
    react_script = globals().get(f"react_pilot_ep_scrpt_{i}")
    if react_script:
        react_blocks = extract_and_partition_scenes(react_script, block_size=4)

        react_script_blocks[i] = {
            f"scene_block_{j+1}": block for j, block in enumerate(react_blocks.values())
        }
        for key, block in react_script_blocks[i].items():
            globals()[f"{key}_ep{i}_react"] = block
    else:
        print(f"⚠️ ReAct script for episode {i} not found")

# %% [markdown]
# ## ReAct Evaluation

# %% [markdown]
# ### Episode 1

# %%
# Evaluate ReAct Episode 1 using scene descriptions and generated script blocks
react_evaluations_ep1 = evaluate_episode_blocks(
    client=client,
    episode_num=1,
    script_blocks=react_script_blocks[1],
    description_blocks=scene_description_blocks[1],
    episode_concept=episode_concept_1
)

# %%
# Access and print all scene block evaluations for Episode 1 (ReAct version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (ReAct) {'=' * 20}\n")
    print(react_evaluations_ep1[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, with a clear progression of events. However, there is some confusion in Scene 3 where Mr. Bianchi is introduced, but it's unclear if this is Frankie's alias or a different character. This inconsistency slightly disrupts the coherence.
# - Relevance: 9 – The scenes support the episode concept well, introducing the main characters and setting up their dynamics. The scenes also hint at the character arcs, with Isabella's adaptability and Frankie's laid-back attitude. However, the subplot with Frankie's parole officer, Gary, is not introduced in these scenes.
# - Interestingness: 7 – The scenes are engaging and set up an interesting dynamic between Frankie and Isabella. However, the narrative could be more dynamic with the introduction of more conflict or unexpected events.
# - Humor: 8 – The comedy is well-timed and character-driven, with humor arising from the characters' interactions and personalities. However, the humor could be more varied, as it currently relies heavily on laugh tracks after one-liners.
# - Overall Quality: 8 – The structure of the scenes is solid, and the tone is consistent with the sitcom genre. The writing is polished, but there is room for improvement in terms of narrative dynamics and humor variety. The introduction of Frankie's parole officer, Gary, would also enhance the overall quality by adding another layer of conflict and complexity.
#
# ==================== Scene Block 2 Evaluation (ReAct) ====================
#
# - Coherence: 6 – The scenes are generally coherent, but there are inconsistencies in the characters' roles and settings. For example, Frankie is a locksmith in Scene 5, a baker in Scene 6, and then a locksmith again in Scene 7. This inconsistency can be confusing for the audience.
# - Relevance: 7 – The scenes are relevant to the episode concept, as they explore the dynamics between Frankie, Isabella, and Gary. However, the sudden shift from locksmith shop to bakery and back again doesn't align with the initial concept of Isabella managing Frankie's locksmith shop.
# - Interestingness: 8 – The scenes are engaging and full of character-driven humor. The interactions between Frankie, Isabella, and Gary are entertaining and provide opportunities for character development.
# - Humor: 8 – The humor is well-timed and character-driven, with a good mix of verbal and situational comedy. The laugh track helps to highlight the comedic moments.
# - Overall Quality: 7 – The scenes are well-structured and the tone is consistent, but the inconsistencies in character roles and settings detract from the overall quality. The writing is polished and the humor is effective, but the narrative could be more focused on the initial concept.
#
# ==================== Scene Block 3 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, there is a slight inconsistency in the setting between scenes 9 and 10, where the comedy night seems to shift from the key shop to a comedy club.
# - Relevance: 9 – The scenes support the episode concept, character arcs, and prior developments well. They continue to explore the dynamic between Frankie, Isabella, and Gary, and further develop the comedy night subplot.
# - Interestingness: 7 – The scenes are engaging and narratively dynamic, but the concept of a comedy night at a locksmith shop is not particularly original. However, the unique character interactions and the subplot of Isabella wanting to start an alpaca-themed bakery add a layer of intrigue.
# - Humor: 8 – The comedy is well-timed and character-driven, with a good mix of situational humor, puns, and character-based jokes. However, the humor could be more varied, as it relies heavily on puns and laugh tracks.
# - Overall Quality: 8 – The structure, tone, and genre fit are all solid, and the writing is polished. The scenes successfully blend comedy with character development and plot progression. However, the humor could be more varied and the setting inconsistency between scenes 9 and 10 slightly detracts from the overall quality.
#
# ==================== Scene Block 4 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, there is a slight inconsistency in Frankie's character, as he is a locksmith in scenes 13 and 14, but a coffee shop owner in scenes 15 and 16. This could be clarified with a line about Frankie owning multiple businesses or a career change.
#
# - Relevance: 7 – The scenes support the episode concept and character arcs, particularly the relationship between Frankie and Isabella. However, the scenes don't seem to directly address the subplot involving Gary, the parole officer, stirring up trouble, which was part of the core concept.
#
# - Interestingness: 9 – The scenes are original and engaging, with a unique setting and a fun mix of characters. The narrative is dynamic, with a good balance of comedy and heartfelt moments. The key and locksmith theme is cleverly woven throughout the scenes.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of jokes, physical comedy, and humorous situations. The humor is consistent with the sitcom genre, although some of the laugh track placements feel a bit forced.
#
# - Overall Quality: 8 – The structure, tone, and genre fit are all strong, and the writing is polished. The scenes are entertaining and have a good balance of humor and character development. However, the scenes could be improved by addressing the subplot involving Gary and clarifying Frankie's career.
#
# ==================== Scene Block 5 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, there is a slight confusion in Scene 20 where Frankie is referred to as Gary's teenage daughter, which contradicts the earlier scenes where she is portrayed as an adult and Frankie's estranged daughter.
# - Relevance: 9 – The scenes support the episode concept, character arcs, and prior developments well. They continue to explore the dynamic between Frankie, Isabella, and Gary, and further develop the locksmith and comedy themes.
# - Interestingness: 7 – The scenes are engaging and narratively dynamic, with a good mix of dialogue, action, and character development. However, the repeated use of lock-picking and key-themed jokes can become predictable and less interesting over time.
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of jokes and humorous situations. The laugh track helps to highlight the comedic moments, although it can feel a bit overused at times.
# - Overall Quality: 8 – The scenes are well-structured and fit the sitcom genre well. The tone is light and humorous, and the writing is polished. However, there is room for improvement in terms of narrative originality and character development.

# %%
# Extract scores into a DataFrame for ReAct Episode 1
react_scores_ep1_df = extract_evaluation_scores(
    react_evaluations_ep1,
    episode_number=1,
    version_label="ReAct"
)

display(react_scores_ep1_df)
# Out:
#     episode version    scene_block        criterion  score  \
# 0         1   ReAct  scene_block_1        Coherence      8
# 1         1   ReAct  scene_block_1        Relevance      9
# 2         1   ReAct  scene_block_1  Interestingness      7
# 3         1   ReAct  scene_block_1            Humor      8
# 4         1   ReAct  scene_block_1  Overall Quality      8
# 5         1   ReAct  scene_block_2        Coherence      6
# 6         1   ReAct  scene_block_2        Relevance      7
# 7         1   ReAct  scene_block_2  Interestingness      8
# 8         1   ReAct  scene_block_2            Humor      8
# 9         1   ReAct  scene_block_2  Overall Quality      7
# 10        1   ReAct  scene_block_3        Coherence      8
# 11        1   ReAct  scene_block_3        Relevance      9
# 12        1   ReAct  scene_block_3  Interestingness      7
# 13        1   ReAct  scene_block_3            Humor      8
# 14        1   ReAct  scene_block_3  Overall Quality      8
# 15        1   ReAct  scene_block_4        Coherence      8
# 16        1   ReAct  scene_block_4        Relevance      7
# 17        1   ReAct  scene_block_4  Interestingness      9
# 18        1   ReAct  scene_block_4            Humor      8
# 19        1   ReAct  scene_block_4  Overall Quality      8
# 20        1   ReAct  scene_block_5        Coherence      8
# 21        1   ReAct  scene_block_5        Relevance      9
# 22        1   ReAct  scene_block_5  Interestingness      7
# 23        1   ReAct  scene_block_5            Humor      8
# 24        1   ReAct  scene_block_5  Overall Quality      8
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes support the episode concept well, i...
# 2   The scenes are engaging and set up an interest...
# 3   The comedy is well-timed and character-driven,...
# 4   The structure of the scenes is solid, and the ...
# 5   The scenes are generally coherent, but there a...
# 6   The scenes are relevant to the episode concept...
# 7   The scenes are engaging and full of character-...
# 8   The humor is well-timed and character-driven, ...
# 9   The scenes are well-structured and the tone is...
# 10  The scenes flow logically from one to the next...
# 11  The scenes support the episode concept, charac...
# 12  The scenes are engaging and narratively dynami...
# 13  The comedy is well-timed and character-driven,...
# 14  The structure, tone, and genre fit are all sol...
# 15  The scenes flow logically from one to the next...
# 16  The scenes support the episode concept and cha...
# 17  The scenes are original and engaging, with a u...
# 18  The comedy is well-timed and character-driven,...
# 19  The structure, tone, and genre fit are all str...
# 20  The scenes flow logically from one to the next...
# 21  The scenes support the episode concept, charac...
# 22  The scenes are engaging and narratively dynami...
# 23  The comedy is well-timed and character-driven,...
# 24  The scenes are well-structured and fit the sit...

# %% [markdown]
# ### Episode 2

# %%
# Evaluate ReAct Episode 2 using scene descriptions and generated script blocks
react_evaluations_ep2 = evaluate_episode_blocks(
    client=client,
    episode_num=2,
    script_blocks=react_script_blocks[2],
    description_blocks=scene_description_blocks[2],
    episode_concept=episode_concept_2,
)

# %%
# Access and print all scene block evaluations for Episode 2 (ReAct version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (ReAct) {'=' * 20}\n")
    print(react_evaluations_ep2[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, the introduction of Lisa in Scene 3 could have been better established, as her relationship to Jimmy is not immediately clear.
# - Relevance: 9 – The scenes support the episode concept well, showing Jimmy's struggles and triumphs as a locksmith. The character arcs are also well established, with Jimmy's relationship with Lisa and his interactions with his customers and neighbors providing depth to his character.
# - Interestingness: 7 – The scenes are engaging and provide a good mix of character development and humor. However, the narrative could be more dynamic, with more unexpected twists or conflicts to keep the audience engaged.
# - Humor: 8 – The comedy is well-timed and character-driven, with Jimmy's lock-related puns and interactions with his customers providing much of the humor. The humor could be more varied, however, as the reliance on puns and slapstick might become repetitive over time.
# - Overall Quality: 8 – The structure, tone, and genre fit of the scenes are well executed, and the writing is polished. The scenes successfully establish the sitcom's premise and characters, and provide a good mix of humor and character development. However, the narrative could be more dynamic and the humor more varied to keep the audience engaged.
#
# ==================== Scene Block 2 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining internal consistency. The characters' personalities and motivations are clear and consistent. However, the transition from Stanley's office to the locksmith workshop could be smoother.
# - Relevance: 9 – The scenes support the episode concept, character arcs, and prior developments well. They further establish the characters' personalities and relationships, and the conflict between Jimmy's traditional methods and Lisa's modern approach is explored in depth.
# - Interestingness: 7 – The scenes are engaging and narratively dynamic, with a good mix of character development and comedic moments. However, the concept of a Broadway-loving parole officer and the conflict between old and new methods is not particularly original.
# - Humor: 7 – The comedy is well-timed and character-driven, with a good variety of jokes. However, some of the humor relies heavily on laugh tracks and may not be as funny without them. The humor could also be more varied, as many of the jokes revolve around Stanley's love for Broadway and the conflict between old and new methods.
# - Overall Quality: 8 – The structure, tone, and genre fit are all solid, and the writing is polished. The characters are well-developed and the conflict is clear. However, the humor could be more varied and the concept could be more original.
#
# ==================== Scene Block 3 Evaluation (ReAct) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and dialogue are consistent with their established personalities. The only minor issue is the confusion about Stanley's role in Scene 10, where he's referred to as a "quirky co-worker" instead of a parole officer.
#
# - Relevance: 10 – The scenes support the episode concept, character arcs, and prior developments. They continue to explore Jimmy's struggle with technology, Lisa's efforts to modernize the business, and Stanley's Broadway-inspired humor. The scenes also set up future plot points, such as Jimmy and Lisa's friendly competition.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of character interaction, humor, and plot development. However, the concept of a technophobic character struggling with modern technology is not particularly original.
#
# - Humor: 9 – The comedy is well-timed and character-driven, with a good variety of jokes, physical comedy, and humorous situations. The Broadway references add a unique twist to the humor. However, the laugh track might feel a bit overused to some viewers.
#
# - Overall Quality: 9 – The scenes are well-structured, with a consistent tone and good fit for the sitcom genre. The writing is polished, with clear dialogue and effective use of humor. The characters are likable and their interactions feel natural. The only minor issues are the slight confusion about Stanley's role in Scene 10 and the somewhat overused laugh track.
#
# ==================== Scene Block 4 Evaluation (ReAct) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative thread. The characters' actions and reactions are consistent with their established personalities. The only minor issue is the sudden introduction of Bob in Scene 16, which could be a bit confusing.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They continue to explore the theme of Jimmy's struggle with technology and his relationship with Lisa, while also incorporating Stanley's Broadway-inspired humor.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of character development, humor, and plot progression. However, the concept of a technologically-challenged individual learning to adapt is not entirely original.
#
# - Humor: 9 – The comedy is well-timed and character-driven, with a good variety of jokes, from Jimmy's confusion over technology to Stanley's Broadway references. The humor is also used effectively to lighten the more serious moments.
#
# - Overall Quality: 9 – The scenes are well-structured, with a good balance of humor, drama, and character development. The tone is consistent with the sitcom genre, and the writing is polished and engaging. The only minor issue is the somewhat abrupt introduction of Bob in Scene 16.
#
# ==================== Scene Block 5 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, the transition from Scene 19 to Scene 20 is a bit abrupt, as it introduces new characters without much context.
# - Relevance: 9 – The scenes support the episode concept and character arcs well. Jimmy's struggle with understanding technology and his relationship with Lisa are highlighted. Stanley's Broadway-inspired antics are also consistent with his character introduction.
# - Interestingness: 7 – The scenes are engaging and narratively dynamic, with a mix of comedic and heartwarming moments. However, they could benefit from more originality, as some of the humor feels a bit predictable.
# - Humor: 7 – The comedy is character-driven and appropriately varied, with a mix of physical comedy, wordplay, and situational humor. However, the timing of the laugh track sometimes feels forced, and some jokes are repeated too often.
# - Overall Quality: 8 – The structure, tone, and genre fit are all solid, and the writing is polished. However, the humor could be improved, and the introduction of new characters in Scene 20 could be better integrated into the narrative.

# %%
# Extract scores into a DataFrame for ReAct Episode 2
react_scores_ep2_df = extract_evaluation_scores(
    react_evaluations_ep2,
    episode_number=2,
    version_label="ReAct"
)

display(react_scores_ep2_df)
# Out:
#     episode version    scene_block        criterion  score  \
# 0         2   ReAct  scene_block_1        Coherence      8
# 1         2   ReAct  scene_block_1        Relevance      9
# 2         2   ReAct  scene_block_1  Interestingness      7
# 3         2   ReAct  scene_block_1            Humor      8
# 4         2   ReAct  scene_block_1  Overall Quality      8
# 5         2   ReAct  scene_block_2        Coherence      8
# 6         2   ReAct  scene_block_2        Relevance      9
# 7         2   ReAct  scene_block_2  Interestingness      7
# 8         2   ReAct  scene_block_2            Humor      7
# 9         2   ReAct  scene_block_2  Overall Quality      8
# 10        2   ReAct  scene_block_3        Coherence      9
# 11        2   ReAct  scene_block_3        Relevance     10
# 12        2   ReAct  scene_block_3  Interestingness      8
# 13        2   ReAct  scene_block_3            Humor      9
# 14        2   ReAct  scene_block_3  Overall Quality      9
# 15        2   ReAct  scene_block_4        Coherence      9
# 16        2   ReAct  scene_block_4        Relevance     10
# 17        2   ReAct  scene_block_4  Interestingness      8
# 18        2   ReAct  scene_block_4            Humor      9
# 19        2   ReAct  scene_block_4  Overall Quality      9
# 20        2   ReAct  scene_block_5        Coherence      8
# 21        2   ReAct  scene_block_5        Relevance      9
# 22        2   ReAct  scene_block_5  Interestingness      7
# 23        2   ReAct  scene_block_5            Humor      7
# 24        2   ReAct  scene_block_5  Overall Quality      8
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes support the episode concept well, s...
# 2   The scenes are engaging and provide a good mix...
# 3   The comedy is well-timed and character-driven,...
# 4   The structure, tone, and genre fit of the scen...
# 5   The scenes flow logically from one to the next...
# 6   The scenes support the episode concept, charac...
# 7   The scenes are engaging and narratively dynami...
# 8   The comedy is well-timed and character-driven,...
# 9   The structure, tone, and genre fit are all sol...
# 10  The scenes flow logically from one to the next...
# 11  The scenes support the episode concept, charac...
# 12  The scenes are engaging and narratively dynami...
# 13  The comedy is well-timed and character-driven,...
# 14  The scenes are well-structured, with a consist...
# 15  The scenes flow logically from one to the next...
# 16  The scenes are highly relevant to the episode ...
# 17  The scenes are engaging and narratively dynami...
# 18  The comedy is well-timed and character-driven,...
# 19  The scenes are well-structured, with a good ba...
# 20  The scenes flow logically from one to the next...
# 21  The scenes support the episode concept and cha...
# 22  The scenes are engaging and narratively dynami...
# 23  The comedy is character-driven and appropriate...
# 24  The structure, tone, and genre fit are all sol...

# %% [markdown]
# ### Episode 3

# %%
# Evaluate ReAct Episode 3 using scene descriptions and generated script blocks
react_evaluations_ep3 = evaluate_episode_blocks(
    client=client,
    episode_num=3,
    script_blocks=react_script_blocks[3],
    description_blocks=scene_description_blocks[3],
    episode_concept=episode_concept_3,
)

# %%
# Access and print all scene block evaluations for Episode 3 (ReAct version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (ReAct) {'=' * 20}\n")
    print(react_evaluations_ep3[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent tone and setting. However, the introduction of Sophie, Jimmy's estranged daughter, is missing from these scenes, which is a key part of the episode's concept.
# - Relevance: 7 – The scenes support the episode concept of Jimmy's life as a locksmith and his interactions with his friends and neighbors. However, the character arcs and prior developments are not clearly established in these scenes. The mysterious package from Jimmy's past is introduced, but its significance is not fully explored.
# - Interestingness: 8 – The scenes are original and engaging, with a variety of comedic situations and character interactions. The use of a locksmith shop as the main setting is unique and provides opportunities for interesting narrative dynamics. However, the scenes could benefit from more dramatic tension or conflict to heighten the stakes.
# - Humor: 9 – The comedy is well-timed and character-driven, with a good variety of jokes and humorous situations. The laugh track helps to punctuate the comedic moments. The humor is consistent with the sitcom genre and adds to the overall enjoyment of the scenes.
# - Overall Quality: 8 – The scenes are well-structured and the tone is consistent with the sitcom genre. The writing is polished and the characters are distinct and engaging. However, the scenes could benefit from more development of the main plot and character arcs.
#
# ==================== Scene Block 2 Evaluation (ReAct) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The only minor issue is the sudden introduction of the intervention room in Scene 8, which could have been foreshadowed earlier.
# - Relevance: 10 – Each scene supports the episode concept and character arcs. Jimmy's locksmith skills are highlighted, Earl's bumbling nature is showcased, and Sophie's return is woven into the narrative effectively. The mysterious package from Jimmy's past is also referenced.
# - Interestingness: 8 – The scenes are engaging and original, with a good mix of humor, heart, and suspense. However, the use of common sitcom tropes (like the exploding coffee maker and cheese puff box) slightly reduces the originality score.
# - Humor: 9 – The comedy is well-timed and character-driven, with a good variety of physical comedy, wordplay, and situational humor. The humor is also used effectively to lighten more serious moments.
# - Overall Quality: 9 – The structure, tone, and genre fit are all excellent, and the writing is polished. The scenes balance humor and heart well, and the characters are well-developed and likable. The only minor issue is the overuse of some sitcom tropes, but this is a minor issue in an otherwise strong scene block.
#
# ==================== Scene Block 3 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, there is a slight inconsistency in the character roles between scenes. In Scene 9 and 11, Jimmy is portrayed as the experienced locksmith and Sophie as the novice, but in Scene 11, their roles are reversed.
#
# - Relevance: 9 – The scenes support the episode concept, character arcs, and prior developments well. They continue the narrative of Jimmy and Sophie's relationship, as well as Earl's comedic mishaps. However, the mysterious package from Jimmy's past mentioned in the episode concept is not addressed in these scenes.
#
# - Interestingness: 7 – The scenes are engaging and narratively dynamic, with a good mix of humor and character development. However, they lack a certain level of originality, as they rely heavily on traditional sitcom tropes and setups.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of physical comedy, wordplay, and situational humor. However, some of the jokes may feel a bit predictable or overused.
#
# - Overall Quality: 8 – The structure, tone, and genre fit are all solid, and the writing is polished. The scenes successfully balance humor with character development and narrative progression. However, the scenes could benefit from more originality and consistency in character roles.
#
# ==================== Scene Block 4 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, there are a few minor inconsistencies, such as the sudden appearance of a mysterious room in Scene 14 and the unclear location of Earl's shop in Scene 15.
# - Relevance: 9 – The scenes support the episode concept and character arcs well. The relationship between Jimmy and Sophie is developed, and the mysterious package from Jimmy's past is introduced. Earl's personal issues are also explored, adding depth to his character.
# - Interestingness: 7 – The scenes are engaging and narratively dynamic, with a good mix of character development, humor, and plot progression. However, the originality is somewhat lacking, with many of the comedic moments relying on familiar sitcom tropes.
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of humor types. The laugh track is used effectively to punctuate the jokes, although some may find it overused.
# - Overall Quality: 8 – The scenes are well-structured and the tone is consistent with the sitcom genre. The writing is polished, with good dialogue and description. However, there is room for improvement in terms of originality and coherence.
#
# ==================== Scene Block 5 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to another, maintaining a consistent narrative. However, the transition from the locksmith shop to the police station in Scene 18 is a bit abrupt and could use more context.
# - Relevance: 9 – The scenes support the episode concept and character arcs well. They build on the relationships established in previous scenes and further develop the characters' personalities and dynamics. The only minor issue is the lack of reference to the mysterious package from Jimmy's past.
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of character development, humor, and plot progression. However, they could benefit from a bit more originality, particularly in the comedic elements.
# - Humor: 7 – The comedy is character-driven and appropriately varied, with a mix of physical comedy, wordplay, and situational humor. However, the timing of the laugh track can sometimes feel forced, and some of the jokes are a bit predictable.
# - Overall Quality: 8 – The structure, tone, and genre fit are all solid, and the writing is polished. The scenes effectively balance humor with character development and plot progression. However, they could benefit from a bit more originality and subtlety in the humor, as well as a stronger connection to the overarching plot.

# %%
# Extract scores into a DataFrame for ReAct Episode 3
react_scores_ep3_df = extract_evaluation_scores(
    react_evaluations_ep3,
    episode_number=3,
    version_label="ReAct"
)

display(react_scores_ep3_df)
# Out:
#     episode version    scene_block        criterion  score  \
# 0         3   ReAct  scene_block_1        Coherence      8
# 1         3   ReAct  scene_block_1        Relevance      7
# 2         3   ReAct  scene_block_1  Interestingness      8
# 3         3   ReAct  scene_block_1            Humor      9
# 4         3   ReAct  scene_block_1  Overall Quality      8
# 5         3   ReAct  scene_block_2        Coherence      9
# 6         3   ReAct  scene_block_2        Relevance     10
# 7         3   ReAct  scene_block_2  Interestingness      8
# 8         3   ReAct  scene_block_2            Humor      9
# 9         3   ReAct  scene_block_2  Overall Quality      9
# 10        3   ReAct  scene_block_3        Coherence      8
# 11        3   ReAct  scene_block_3        Relevance      9
# 12        3   ReAct  scene_block_3  Interestingness      7
# 13        3   ReAct  scene_block_3            Humor      8
# 14        3   ReAct  scene_block_3  Overall Quality      8
# 15        3   ReAct  scene_block_4        Coherence      8
# 16        3   ReAct  scene_block_4        Relevance      9
# 17        3   ReAct  scene_block_4  Interestingness      7
# 18        3   ReAct  scene_block_4            Humor      8
# 19        3   ReAct  scene_block_4  Overall Quality      8
# 20        3   ReAct  scene_block_5        Coherence      8
# 21        3   ReAct  scene_block_5        Relevance      9
# 22        3   ReAct  scene_block_5  Interestingness      8
# 23        3   ReAct  scene_block_5            Humor      7
# 24        3   ReAct  scene_block_5  Overall Quality      8
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes support the episode concept of Jimm...
# 2   The scenes are original and engaging, with a v...
# 3   The comedy is well-timed and character-driven,...
# 4   The scenes are well-structured and the tone is...
# 5   The scenes flow logically from one to the next...
# 6   Each scene supports the episode concept and ch...
# 7   The scenes are engaging and original, with a g...
# 8   The comedy is well-timed and character-driven,...
# 9   The structure, tone, and genre fit are all exc...
# 10  The scenes flow logically from one to the next...
# 11  The scenes support the episode concept, charac...
# 12  The scenes are engaging and narratively dynami...
# 13  The comedy is well-timed and character-driven,...
# 14  The structure, tone, and genre fit are all sol...
# 15  The scenes flow logically from one to the next...
# 16  The scenes support the episode concept and cha...
# 17  The scenes are engaging and narratively dynami...
# 18  The comedy is well-timed and character-driven,...
# 19  The scenes are well-structured and the tone is...
# 20  The scenes flow logically from one to another,...
# 21  The scenes support the episode concept and cha...
# 22  The scenes are engaging and narratively dynami...
# 23  The comedy is character-driven and appropriate...
# 24  The structure, tone, and genre fit are all sol...

# %% [markdown]
# ### Episode 4

# %%
# Evaluate ReAct Episode 4 using scene descriptions and generated script blocks
react_evaluations_ep4 = evaluate_episode_blocks(
    client=client,
    episode_num=4,
    script_blocks=react_script_blocks[4],
    description_blocks=scene_description_blocks[4],
    episode_concept=episode_concept_4,
)

# %%
# Access and print all scene block evaluations for Episode 4 (ReAct version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (ReAct) {'=' * 20}\n")
    print(react_evaluations_ep4[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (ReAct) ====================
#
# - Coherence: 7 – The scenes generally flow logically, but there are some inconsistencies. For example, in Scene 2, the setting is described as "Jimmy's Novelty Shop," but in all other scenes, it's a locksmith shop. Also, in Scene 1, Lucy is introduced as a new employee, but she doesn't appear in the following scenes.
# - Relevance: 8 – The scenes support the episode concept and character arcs well. We see Jimmy's transition from a solo locksmith to a business partner with his daughter, Samantha. Samantha's eco-friendly ideas and Jimmy's old-school approach create a nice dynamic. However, Lucy's introduction in Scene 1 doesn't seem to have any follow-up.
# - Interestingness: 8 – The scenes are engaging and narratively dynamic. The introduction of Samantha's eco-friendly ideas and Terry's eccentric character add interesting elements to the story. However, the scenes could benefit from more conflict or unexpected turns.
# - Humor: 7 – The humor is character-driven and appropriately varied, with a mix of physical comedy (Jimmy bumping his head, Terry causing chaos) and witty dialogue. However, some of the jokes are a bit predictable and could be more original.
# - Overall Quality: 7.5 – The scenes are well-structured and the tone is consistent, fitting the sitcom genre well. The writing is polished, but there are some inconsistencies and missed opportunities for more original humor and interesting plot developments.
#
# ==================== Scene Block 2 Evaluation (ReAct) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and dialogue are consistent with their established personalities. The only minor issue is the sudden shift in location from the locksmith shop to a cafe in Scene 6, which could have been better transitioned.
#
# - Relevance: 10 – Each scene supports the episode concept and builds on the characters' arcs. Jimmy's past as a convict is subtly referenced, Samantha's business school knowledge is put to use, and Terry's eccentricity is showcased. The scenes also build on the father-daughter relationship and their shared business venture.
#
# - Interestingness: 8 – The scenes are engaging and original, with a good mix of character development, humor, and plot progression. The eco-friendly lock idea adds a unique twist to the locksmith shop setting. However, some of the humor, such as the repeated coffee spills, could be seen as a bit predictable.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good mix of physical humor, wordplay, and situational comedy. The humor is also appropriately varied, with each character having their own comedic style. However, some of the jokes, like the coffee spills and the rubber chicken, might be seen as a bit clichéd.
#
# - Overall Quality: 9 – The scenes are well-structured, with a good balance of humor, character development, and plot progression. The tone is consistent with a sitcom, and the writing is polished. The characters are likable and their interactions are entertaining. The only minor issue is the occasional predictability of the humor.
#
# ==================== Scene Block 3 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, there is a slight inconsistency in Scene 11 where Jimmy and Samantha are suddenly working in a music shop, which is not explained or connected to the locksmith shop.
# - Relevance: 7 – The scenes support the episode concept and character arcs, with Jimmy and Samantha's relationship developing and their personalities shining through. However, the scenes in the music shop and office don't directly relate to the locksmith shop setting established in the pilot.
# - Interestingness: 8 – The scenes are original and engaging, with a variety of settings and situations that keep the narrative dynamic. The eco-friendly theme adds an interesting twist to the sitcom format.
# - Humor: 9 – The comedy is well-timed and character-driven, with a good variety of humor types, from physical comedy to wordplay. The characters' unique traits, such as Jimmy's clumsiness and Samantha's quick wit, contribute to the humor.
# - Overall Quality: 8 – The structure, tone, and genre fit are all strong, and the writing is polished. However, the scenes could be more tightly connected to the core concept of the locksmith shop. The humor and character development are the standout elements.
#
# ==================== Scene Block 4 Evaluation (ReAct) ====================
#
# - Coherence: 3 – The scenes are internally consistent, but they don't flow logically from one to the next. The characters and settings change abruptly, making it hard to follow the narrative thread.
# - Relevance: 2 – The scenes don't seem to support the episode concept, character arcs, or prior developments. The core characters, Jimmy and Samantha, are only present in two scenes, and the locksmith shop setting is largely absent. The scenes seem to belong to different sitcoms.
# - Interestingness: 5 – The scenes are original and engaging, with a variety of settings and characters. However, they lack narrative dynamism due to the abrupt changes and lack of connection to the core concept.
# - Humor: 6 – The comedy is well-timed and character-driven, with a good variety of humor types. However, the humor is somewhat generic and could be better tailored to the characters and situations.
# - Overall Quality: 4 – The scenes are well-structured and the tone is consistent, but they don't fit the genre or the core concept of the sitcom. The writing is polished, but the scenes lack a clear narrative direction and connection to the episode's premise.
#
# ==================== Scene Block 5 Evaluation (ReAct) ====================
#
# - Coherence: 7 – The scenes are generally coherent, but there are some inconsistencies. For example, Scene 18 seems to be a flashback, but it's not clearly indicated. Also, Scene 20 refers to a customer from Scene 17, but there is no customer in Scene 17.
# - Relevance: 8 – The scenes are mostly relevant to the sitcom's concept and character arcs. They show Jimmy and Samantha's growing bond and their shared experiences. However, Scene 18 seems a bit disconnected from the rest of the scenes, as it doesn't involve the locksmith shop or Samantha.
# - Interestingness: 7 – The scenes are engaging and have some interesting elements, like the squirrel in Scene 17 and the composting idea in Scene 19. However, they could be more dynamic and contain more unexpected developments.
# - Humor: 7 – The humor is character-driven and varied, with physical comedy (like Terry tripping over the mat), wordplay (like the "locksmith's paradox"), and situational humor (like the haggling customer). However, some of the jokes are a bit predictable and could be more original.
# - Overall Quality: 7 – The scenes are well-structured and fit the sitcom genre, but they could be more polished. The dialogue sometimes feels a bit forced, and the laugh tracks are overused. The character development is good, though, and the scenes have a nice balance of humor and sentimentality.

# %%
# Extract scores into a DataFrame for ReAct Episode 4
react_scores_ep4_df = extract_evaluation_scores(
    react_evaluations_ep4,
    episode_number=4,
    version_label="ReAct"
)

display(react_scores_ep4_df)
# Out:
# ⚠️ Skipped unmatched line in scene_block_1: - Overall Quality: 7.5 – The scenes are well-structured and the tone is consistent, fitting the sitcom genre well. The writing is polished, but there are some inconsistencies and missed opportunities for more original humor and interesting plot developments.
#     episode version    scene_block        criterion  score  \
# 0         4   ReAct  scene_block_1        Coherence      7
# 1         4   ReAct  scene_block_1        Relevance      8
# 2         4   ReAct  scene_block_1  Interestingness      8
# 3         4   ReAct  scene_block_1            Humor      7
# 4         4   ReAct  scene_block_2        Coherence      9
# 5         4   ReAct  scene_block_2        Relevance     10
# 6         4   ReAct  scene_block_2  Interestingness      8
# 7         4   ReAct  scene_block_2            Humor      8
# 8         4   ReAct  scene_block_2  Overall Quality      9
# 9         4   ReAct  scene_block_3        Coherence      8
# 10        4   ReAct  scene_block_3        Relevance      7
# 11        4   ReAct  scene_block_3  Interestingness      8
# 12        4   ReAct  scene_block_3            Humor      9
# 13        4   ReAct  scene_block_3  Overall Quality      8
# 14        4   ReAct  scene_block_4        Coherence      3
# 15        4   ReAct  scene_block_4        Relevance      2
# 16        4   ReAct  scene_block_4  Interestingness      5
# 17        4   ReAct  scene_block_4            Humor      6
# 18        4   ReAct  scene_block_4  Overall Quality      4
# 19        4   ReAct  scene_block_5        Coherence      7
# 20        4   ReAct  scene_block_5        Relevance      8
# 21        4   ReAct  scene_block_5  Interestingness      7
# 22        4   ReAct  scene_block_5            Humor      7
# 23        4   ReAct  scene_block_5  Overall Quality      7
#
#                                         justification
# 0   The scenes generally flow logically, but there...
# 1   The scenes support the episode concept and cha...
# 2   The scenes are engaging and narratively dynami...
# 3   The humor is character-driven and appropriatel...
# 4   The scenes flow logically from one to the next...
# 5   Each scene supports the episode concept and bu...
# 6   The scenes are engaging and original, with a g...
# 7   The comedy is well-timed and character-driven,...
# 8   The scenes are well-structured, with a good ba...
# 9   The scenes flow logically from one to the next...
# 10  The scenes support the episode concept and cha...
# 11  The scenes are original and engaging, with a v...
# 12  The comedy is well-timed and character-driven,...
# 13  The structure, tone, and genre fit are all str...
# 14  The scenes are internally consistent, but they...
# 15  The scenes don't seem to support the episode c...
# 16  The scenes are original and engaging, with a v...
# 17  The comedy is well-timed and character-driven,...
# 18  The scenes are well-structured and the tone is...
# 19  The scenes are generally coherent, but there a...
# 20  The scenes are mostly relevant to the sitcom's...
# 21  The scenes are engaging and have some interest...
# 22  The humor is character-driven and varied, with...
# 23  The scenes are well-structured and fit the sit...

# %% [markdown]
# ### Episode 5

# %%
# Evaluate ReAct Episode 5 using scene descriptions and generated script blocks
react_evaluations_ep5 = evaluate_episode_blocks(
    client=client,
    episode_num=5,
    script_blocks=react_script_blocks[5],
    description_blocks=scene_description_blocks[5],
    episode_concept=episode_concept_5
)

# %%
# Access and print all scene block evaluations for Episode 5 (ReAct version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (ReAct) {'=' * 20}\n")
    print(react_evaluations_ep5[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (ReAct) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and reactions are believable and consistent with their established personalities. The only minor issue is the sudden introduction of the parrot in the last scene, which could have been foreshadowed earlier.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They establish Frankie's new life as a locksmith, his relationship with Earl and Len, and his struggle to adapt to his new circumstances. They also introduce the subplot of Frankie's struggle to master locksmithing, which could be a recurring theme in future episodes.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of dialogue, action, and character development. However, they could be more original, as the concept of an ex-convict adjusting to life on the outside is a common trope in sitcoms.
#
# - Humor: 7 – The comedy is well-timed and character-driven, with a good variety of jokes, from Earl's sarcastic remarks to Len's outdated slang. However, the humor relies heavily on laugh tracks, which can feel forced and outdated. Some of the jokes, such as the repeated references to locks and keys, also become repetitive.
#
# - Overall Quality: 8 – The scenes are well-structured and well-written, with a consistent tone and a good fit for the sitcom genre. The characters are likable and their relationships are believable. However, the writing could be polished further to make the humor more natural and less reliant on laugh tracks.
#
# ==================== Scene Block 2 Evaluation (ReAct) ====================
#
# - Coherence: 7 – The scenes generally flow logically, but there are some inconsistencies. For example, in Scene 5, Frankie is an apprentice to Earl, but in Scene 7, he's a middle-aged locksmith. Similarly, in Scene 6, Len is a magician, but in Scene 8, Frankie is the washed-up magician. These inconsistencies can be confusing for the audience.
# - Relevance: 8 – The scenes support the episode concept and character arcs well. Frankie's journey from a nervous apprentice to a confident locksmith is clear, and his relationship with Ellie is developed throughout the scenes. However, the scenes could do more to build on prior developments, such as Frankie's release from prison.
# - Interestingness: 9 – The scenes are original and engaging, with a good mix of comedy and drama. The use of the locksmith shop and magic shop as settings adds a unique twist to the sitcom format. The scenes also do a good job of building tension and intrigue, particularly in the interactions between Frankie and Ellie.
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of jokes and comedic situations. The humor is also well-integrated into the narrative, helping to lighten the mood and add depth to the characters. However, some of the jokes could be more original and less reliant on laugh tracks.
# - Overall Quality: 8 – The scenes are well-structured and well-written, with a good balance of comedy and drama. The characters are well-developed and likable, and the narrative is engaging and original. However, the inconsistencies in the characters' roles and the overuse of laugh tracks detract from the overall quality.
#
# ==================== Scene Block 3 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining internal consistency. However, there is a slight disconnect between Scene 12 and the rest of the scenes, as Frankie is suddenly a barista in a café, which is not explained or connected to the locksmith shop or his past as a magician.
# - Relevance: 9 – The scenes support the episode concept, character arcs, and prior developments well. They continue to explore Frankie's past as a magician, his new life as a locksmith, and his relationship with Ellie and Len. The key and the magic tricks serve as recurring motifs that tie the scenes together.
# - Interestingness: 7 – The scenes are original and engaging, with a good mix of humor, tension, and emotional moments. However, the narrative could be more dynamic, with more unexpected twists or conflicts to keep the audience on their toes.
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of jokes, physical comedy, and humorous situations. However, some of the humor relies heavily on the laugh track, which may not appeal to all viewers.
# - Overall Quality: 8 – The scenes are well-structured, with a consistent tone and a good fit for the sitcom genre. The writing is polished, with clear character voices and effective use of dialogue and action. However, there is room for improvement in terms of narrative complexity and humor.
#
# ==================== Scene Block 4 Evaluation (ReAct) ====================
#
# - Coherence: 8 – The scenes are mostly coherent and flow logically. However, Scene 14 is a bit confusing as the characters are not named, making it hard to understand who is who and how they relate to the main characters.
# - Relevance: 7 – The scenes generally support the episode concept and character arcs. However, Frankie's magician attire in Scene 13 seems out of place given the locksmith theme. Scene 14 also seems disconnected from the main storyline.
# - Interestingness: 8 – The scenes are engaging and narratively dynamic. The interactions between Frankie, Ellie, and Len are interesting, and the subplot of Frankie learning the locksmith trade adds a unique twist. However, the unnamed characters in Scene 14 detract from the overall interest.
# - Humor: 9 – The comedy is well-timed and character-driven. The humor is appropriately varied, with a mix of physical comedy, wordplay, and situational humor. The running gag of Frankie's confusion over idioms is particularly amusing.
# - Overall Quality: 8 – The structure, tone, and genre fit are generally good, and the writing is polished. However, the coherence and relevance issues in Scene 14 and the magician subplot in Scene 13 slightly lower the overall quality.
#
# ==================== Scene Block 5 Evaluation (ReAct) ====================
#
# - Coherence: 7 – The scenes are generally coherent, but there are some inconsistencies. For example, Scene 17 introduces new characters (Lily, Max, Gus) who are not mentioned in the pilot episode concept or previous scenes. Scene 20 also introduces new characters (Jerry, Ted, Lucy) who are not connected to the main characters. However, the actions and dialogues within each scene are logically connected and maintain internal consistency.
# - Relevance: 6 – Scenes 18 and 19 are relevant to the episode concept and character arcs, as they involve Frankie and Ellie, the main characters. However, Scenes 17 and 20 introduce new characters and settings that are not directly related to the main plot or characters. These scenes seem to be more of standalone vignettes rather than integral parts of the episode.
# - Interestingness: 8 – The scenes are generally engaging and narratively dynamic. They introduce a variety of situations and conflicts, such as the struggle to modernize the locksmith shop, the malfunctioning game booth at the carnival, and the challenge of unlocking a stubborn lock. These situations provide opportunities for character development and humor.
# - Humor: 8 – The comedy is well-timed and character-driven, with a good mix of verbal humor, situational humor, and character humor. The humor is appropriately varied, with different types of jokes and comedic situations in each scene.
# - Overall Quality: 7 – The scenes are well-structured and well-written, with a clear beginning, middle, and end. The tone is consistent with the genre of a sitcom, with a balance of humor and heart. However, the scenes could be improved by better integrating them into the main plot and character arcs. The introduction of new characters and settings in Scenes 17 and 20 is somewhat confusing and detracts from the overall coherence and relevance of the scene block.

# %%
# Extract scores into a DataFrame for ReAct Episode 5
react_scores_ep5_df = extract_evaluation_scores(
    react_evaluations_ep5,
    episode_number=5,
    version_label="ReAct"
)

display(react_scores_ep5_df)
# Out:
#     episode version    scene_block        criterion  score  \
# 0         5   ReAct  scene_block_1        Coherence      9
# 1         5   ReAct  scene_block_1        Relevance     10
# 2         5   ReAct  scene_block_1  Interestingness      8
# 3         5   ReAct  scene_block_1            Humor      7
# 4         5   ReAct  scene_block_1  Overall Quality      8
# 5         5   ReAct  scene_block_2        Coherence      7
# 6         5   ReAct  scene_block_2        Relevance      8
# 7         5   ReAct  scene_block_2  Interestingness      9
# 8         5   ReAct  scene_block_2            Humor      8
# 9         5   ReAct  scene_block_2  Overall Quality      8
# 10        5   ReAct  scene_block_3        Coherence      8
# 11        5   ReAct  scene_block_3        Relevance      9
# 12        5   ReAct  scene_block_3  Interestingness      7
# 13        5   ReAct  scene_block_3            Humor      8
# 14        5   ReAct  scene_block_3  Overall Quality      8
# 15        5   ReAct  scene_block_4        Coherence      8
# 16        5   ReAct  scene_block_4        Relevance      7
# 17        5   ReAct  scene_block_4  Interestingness      8
# 18        5   ReAct  scene_block_4            Humor      9
# 19        5   ReAct  scene_block_4  Overall Quality      8
# 20        5   ReAct  scene_block_5        Coherence      7
# 21        5   ReAct  scene_block_5        Relevance      6
# 22        5   ReAct  scene_block_5  Interestingness      8
# 23        5   ReAct  scene_block_5            Humor      8
# 24        5   ReAct  scene_block_5  Overall Quality      7
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes are highly relevant to the episode ...
# 2   The scenes are engaging and narratively dynami...
# 3   The comedy is well-timed and character-driven,...
# 4   The scenes are well-structured and well-writte...
# 5   The scenes generally flow logically, but there...
# 6   The scenes support the episode concept and cha...
# 7   The scenes are original and engaging, with a g...
# 8   The comedy is well-timed and character-driven,...
# 9   The scenes are well-structured and well-writte...
# 10  The scenes flow logically from one to the next...
# 11  The scenes support the episode concept, charac...
# 12  The scenes are original and engaging, with a g...
# 13  The comedy is well-timed and character-driven,...
# 14  The scenes are well-structured, with a consist...
# 15  The scenes are mostly coherent and flow logica...
# 16  The scenes generally support the episode conce...
# 17  The scenes are engaging and narratively dynami...
# 18  The comedy is well-timed and character-driven....
# 19  The structure, tone, and genre fit are general...
# 20  The scenes are generally coherent, but there a...
# 21  Scenes 18 and 19 are relevant to the episode c...
# 22  The scenes are generally engaging and narrativ...
# 23  The comedy is well-timed and character-driven,...
# 24  The scenes are well-structured and well-writte...

# %% [markdown]
# ## Baseline Evaluation

# %%
# Evaluate Baseline Episode 1 using scene descriptions and generated script blocks
baseline_evaluations_ep1 = evaluate_episode_blocks(
    client=client,
    episode_num=1,
    script_blocks=baseline_script_blocks[1],
    description_blocks=scene_description_blocks[1],
    episode_concept=episode_concept_1
)

# %%
# Access and print all scene block evaluations for episode 1 (Baseline version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (Baseline) {'=' * 20}\n")
    print(baseline_evaluations_ep1[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The introduction of characters and their interactions are well-paced and coherent. The only minor issue is the abrupt introduction of Isabella in Scene 3, which could have been hinted at earlier.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept. They introduce the main characters, Frankie and Isabella, and set up their dynamic. The scenes also establish the setting of the locksmith shop and the challenges that come with it.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic. The introduction of Isabella and her subsequent interaction with Frankie adds an interesting twist to the story. However, the scenes could benefit from more unexpected or surprising elements to keep the audience on their toes.
#
# - Humor: 7 – The humor is character-driven and well-timed, with a good mix of situational and dialogue-based comedy. However, some of the jokes are a bit predictable and could benefit from more originality.
#
# - Overall Quality: 8 – The scenes are well-structured and the tone is consistent with the sitcom genre. The writing is polished and the characters are well-developed. However, the humor could be improved and the narrative could benefit from more unexpected elements.
#
# ==================== Scene Block 2 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The introduction of Gary and the ticketing system in Scene 5 sets up the subsequent scenes well. The only minor issue is the sudden introduction of the comedy night idea in Scene 7, which could have been hinted at earlier for better coherence.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They further explore the dynamic between Frankie and Isabella, introduce a new character (Gary), and set up potential future plotlines (the comedy night). The scenes also build on the tension and humor established in the previous scenes.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of character interactions, conflict, and humor. The introduction of the comedy night idea adds an unexpected twist. However, the scenes could be more original, as they rely heavily on familiar sitcom tropes (e.g., the bickering father-daughter duo, the meddling outsider).
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of jokes, from witty banter to physical comedy (the ticketing system falling over). However, some of the humor is a bit predictable and could benefit from more unexpected punchlines.
#
# - Overall Quality: 8 – The scenes are well-structured, with a clear progression of events and a consistent tone. They fit well within the sitcom genre and demonstrate good writing polish. However, they could be improved with more original humor and a more seamless integration of the comedy night idea.
#
# ==================== Scene Block 3 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The only minor issue is the sudden introduction of James, a character who seems to have a familiarity with the shop but hasn't been mentioned before.
# - Relevance: 10 – The scenes perfectly support the episode concept, character arcs, and prior developments. They show the progression of the comedy night idea, the evolving dynamic between Frankie and Isabella, and the comedic role of Gary.
# - Interestingness: 8 – The scenes are original and engaging, with the unusual concept of a comedy night at a locksmith shop. However, the narrative could be more dynamic with some unexpected twists or conflicts.
# - Humor: 9 – The comedy is well-timed and character-driven, with humor arising from the characters' reactions to the unusual situation and to each other. The jokes are appropriately varied, though some of Gary's jokes might be too cheesy for some viewers.
# - Overall Quality: 9 – The scenes are well-structured and the tone is consistent. They fit the sitcom genre well, with a good balance of humor and character development. The writing is polished, with clear and distinct character voices.
#
# ==================== Scene Block 4 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The transition from comedy night to the aftermath and the cleanup is smooth and believable. The only minor issue is the sudden introduction of Margaret in Scene 15, which could have been set up better.
# - Relevance: 10 – The scenes support the episode concept, character arcs, and prior developments perfectly. The comedy night is a direct continuation of the previous scenes, and the interactions between Frankie, Isabella, and Gary further develop their relationships and characters. The scenes also highlight the changing dynamics of the locksmith shop under Isabella's management.
# - Interestingness: 8 – The scenes are original and engaging, with the unique concept of a comedy night at a locksmith shop. The humor and character interactions keep the narrative dynamic. However, the scenes could benefit from a bit more conflict or unexpected developments to increase the tension and interest.
# - Humor: 9 – The comedy is well-timed and character-driven, with the humor arising naturally from the situation and the characters' personalities. The locksmith-themed jokes are a fun touch that adds to the uniqueness of the sitcom. However, the humor could be more varied, as it relies heavily on puns and one-liners.
# - Overall Quality: 9 – The scenes are well-structured, with a clear progression and development. The tone is consistent and fits the sitcom genre well. The writing is polished, with good dialogue and character interactions. The scenes could be improved with a bit more conflict or unexpected developments, and more varied humor.
#
# ==================== Scene Block 5 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and dialogue are consistent with their established personalities and the situation they're in. The only minor issue is the repetition of some jokes and themes, which slightly disrupts the flow.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They continue to explore the dynamic between Frankie, Isabella, and Gary, and further develop the idea of the comedy night at the locksmith shop. The scenes also continue to build on the relationship between Frankie and Isabella, showing their growing bond and mutual respect.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with the characters facing new challenges and opportunities. The idea of a regular comedy night at the locksmith shop is an interesting twist, and Gary's stand-up gig adds another layer of intrigue. However, the scenes could benefit from a bit more conflict or unexpected developments to keep the audience on their toes.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with the humor arising naturally from the characters' interactions and the situation they're in. The locksmith-themed jokes are a fun touch, although they do get a bit repetitive. The humor could be more varied to keep the audience entertained.
#
# - Overall Quality: 9 – The scenes are well-structured and well-written, with a good balance of humor, character development, and plot progression. The tone is consistent with the sitcom genre, and the writing is polished. However, the scenes could benefit from a bit more variety in the humor and a bit more conflict or unexpected developments to keep the audience engaged.

# %%
# Extract scores into a DataFrame for Baseline Episode 1
baseline_scores_ep1_df = extract_evaluation_scores(
    baseline_evaluations_ep1,
    episode_number=1,
    version_label="Baseline"
)

display(baseline_scores_ep1_df)
# Out:
#     episode   version    scene_block        criterion  score  \
# 0         1  Baseline  scene_block_1        Coherence      9
# 1         1  Baseline  scene_block_1        Relevance     10
# 2         1  Baseline  scene_block_1  Interestingness      8
# 3         1  Baseline  scene_block_1            Humor      7
# 4         1  Baseline  scene_block_1  Overall Quality      8
# 5         1  Baseline  scene_block_2        Coherence      9
# 6         1  Baseline  scene_block_2        Relevance     10
# 7         1  Baseline  scene_block_2  Interestingness      8
# 8         1  Baseline  scene_block_2            Humor      8
# 9         1  Baseline  scene_block_2  Overall Quality      8
# 10        1  Baseline  scene_block_3        Coherence      9
# 11        1  Baseline  scene_block_3        Relevance     10
# 12        1  Baseline  scene_block_3  Interestingness      8
# 13        1  Baseline  scene_block_3            Humor      9
# 14        1  Baseline  scene_block_3  Overall Quality      9
# 15        1  Baseline  scene_block_4        Coherence      9
# 16        1  Baseline  scene_block_4        Relevance     10
# 17        1  Baseline  scene_block_4  Interestingness      8
# 18        1  Baseline  scene_block_4            Humor      9
# 19        1  Baseline  scene_block_4  Overall Quality      9
# 20        1  Baseline  scene_block_5        Coherence      9
# 21        1  Baseline  scene_block_5        Relevance     10
# 22        1  Baseline  scene_block_5  Interestingness      8
# 23        1  Baseline  scene_block_5            Humor      8
# 24        1  Baseline  scene_block_5  Overall Quality      9
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes are highly relevant to the episode ...
# 2   The scenes are engaging and narratively dynami...
# 3   The humor is character-driven and well-timed, ...
# 4   The scenes are well-structured and the tone is...
# 5   The scenes flow logically from one to the next...
# 6   The scenes are highly relevant to the episode ...
# 7   The scenes are engaging and narratively dynami...
# 8   The comedy is well-timed and character-driven,...
# 9   The scenes are well-structured, with a clear p...
# 10  The scenes flow logically from one to the next...
# 11  The scenes perfectly support the episode conce...
# 12  The scenes are original and engaging, with the...
# 13  The comedy is well-timed and character-driven,...
# 14  The scenes are well-structured and the tone is...
# 15  The scenes flow logically from one to the next...
# 16  The scenes support the episode concept, charac...
# 17  The scenes are original and engaging, with the...
# 18  The comedy is well-timed and character-driven,...
# 19  The scenes are well-structured, with a clear p...
# 20  The scenes flow logically from one to the next...
# 21  The scenes are highly relevant to the episode ...
# 22  The scenes are engaging and narratively dynami...
# 23  The comedy is well-timed and character-driven,...
# 24  The scenes are well-structured and well-writte...

# %% [markdown]
# ### Episode 2

# %%
# Evaluate Baseline Episode 2 using scene descriptions and generated script blocks
baseline_evaluations_ep2 = evaluate_episode_blocks(
    client=client,
    episode_num=2,
    script_blocks=baseline_script_blocks[2],
    description_blocks=scene_description_blocks[2],
    episode_concept=episode_concept_2
)

# %%
# Access and print all scene block evaluations for Episode 2 (Baseline version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (Baseline) {'=' * 20}\n")
    print(baseline_evaluations_ep2[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The introduction of Lisa is a bit abrupt, but it's a necessary surprise for the plot.
# - Relevance: 8 – The scenes support the episode concept and character arcs well. Jimmy's struggle with the keys and his interaction with Mrs. O'Leary establish his character and the setting. Lisa's introduction and her offer to help modernize the shop introduce a new dynamic. However, the parole officer Stanley is missing from these scenes.
# - Interestingness: 7 – The scenes are engaging and narratively dynamic, with a good mix of humor and emotional moments. The surprise introduction of Lisa adds an interesting twist. However, the scenes could benefit from more conflict or unexpected developments.
# - Humor: 7 – The humor is character-driven and well-timed, with a good mix of physical comedy and witty dialogue. However, some of the jokes are a bit predictable and the laugh track can feel forced.
# - Overall Quality: 8 – The structure, tone, and genre fit are all solid. The writing is polished and the characters are well-drawn. However, the scenes could benefit from more original humor and unexpected plot developments.
#
# ==================== Scene Block 2 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining internal consistency. The introduction of Stanley, the parole officer, is a bit abrupt, but his character is quickly established and integrated into the dynamic between Jimmy and Lisa.
#
# - Relevance: 10 – Each scene supports the episode concept, character arcs, and prior developments. Stanley's introduction adds a new layer to Jimmy's character and his past as an ex-con. Lisa's attempts to modernize the shop and teach Jimmy about technology further develop their relationship and the conflict between their approaches.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good balance of comedy and character development. Stanley's Broadway-inspired antics add a unique twist, and the ongoing tension between Jimmy's old-school methods and Lisa's tech-savvy approach keeps the narrative interesting. However, the locksmithing lesson in Scene 7 is a bit predictable.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with Stanley's Broadway references and Jimmy's skepticism about technology providing most of the humor. The humor is appropriately varied, though some of the laugh track moments feel a bit forced.
#
# - Overall Quality: 9 – The structure, tone, and genre fit are all strong, and the writing is polished. The characters are well-developed and their interactions feel natural. The humor is consistent and the narrative is engaging, though there is room for more originality in the locksmithing scenes.
#
# ==================== Scene Block 3 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining internal consistency. The characters' actions and dialogue are consistent with their established personalities and the situation they're in. The only minor issue is the sudden decision of Lisa to be part of the shop in the last scene, which could have been hinted at earlier.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They continue the story of Jimmy's struggle to adapt to modern technology and Lisa's efforts to help him, while also developing Stanley's character as a supportive and humorous figure.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of humor, character development, and plot progression. However, they could be more original, as the theme of an older person struggling with technology is quite common in sitcoms.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with Stanley's Broadway references and Jimmy's grumbling about technology providing consistent humor. However, the humor could be more varied, as it relies heavily on these two elements.
#
# - Overall Quality: 9 – The scenes are well-structured and well-written, with a good balance of humor, drama, and character development. They fit well within the sitcom genre and maintain a consistent tone. The dialogue is natural and the characters are likable and relatable. The only minor issue is the somewhat predictable plotline of Jimmy struggling with technology.
#
# ==================== Scene Block 4 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and reactions are consistent with their established personalities, and the dialogue is natural and believable. The only minor issue is the sudden introduction of the app idea in the last scene, which could have been hinted at earlier for better coherence.
#
# - Relevance: 10 – The scenes are highly relevant to the episode's concept and the characters' arcs. Jimmy's acceptance of the spreadsheet and his growing trust in Lisa's ideas reflect his character development. The scenes also build on the previous developments, such as the argument about the shop's direction and Stanley's role as a supportive figure.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of humor, character development, and plot progression. The idea of a locksmith shop going digital adds a fresh twist to the story. However, the scenes could benefit from a bit more conflict or unexpected turns to make them more interesting.
#
# - Humor: 7 – The humor is character-driven and well-timed, with the laugh track indicating the punchlines. The running joke about Jimmy's skepticism towards technology and Stanley's surprise at their progress adds a humorous touch. However, the humor could be more varied and less reliant on the laugh track.
#
# - Overall Quality: 8 – The scenes are well-structured, with a good balance of dialogue and action. The tone is consistent with the sitcom genre, and the writing is polished. The character dynamics are well-portrayed, and the plot progression is smooth. However, the scenes could benefit from more unexpected turns and varied humor to enhance their overall quality.
#
# ==================== Scene Block 5 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and reactions are believable and consistent with their established personalities. The only minor issue is the sudden appearance of the boombox in Scene 18, which could use a bit more setup.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They show the successful implementation of Lisa's tech solution, the strengthening of the relationship between Jimmy and Lisa, and the comedic antics of Stanley, all of which are central to the sitcom's premise.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with the successful launch of the app and Stanley's Broadway-inspired celebration adding excitement. However, the scenes could benefit from a bit more conflict or unexpected developments to increase the narrative tension.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with Stanley's Broadway antics and Jimmy's sarcastic comments providing humor. However, the humor could be more varied, as it relies heavily on laugh tracks and could incorporate more visual or situational comedy.
#
# - Overall Quality: 9 – The scenes are well-structured, maintain a consistent tone, and fit well within the sitcom genre. The writing is polished, with clear dialogue and effective use of stage directions. The scenes could be improved with a bit more narrative tension and varied humor, but overall, they are of high quality.

# %%
# Extract scores into a DataFrame for Baseline Episode 2
baseline_scores_ep2_df = extract_evaluation_scores(
    baseline_evaluations_ep2,
    episode_number=2,
    version_label="Baseline"
)

display(baseline_scores_ep2_df)
# Out:
#     episode   version    scene_block        criterion  score  \
# 0         2  Baseline  scene_block_1        Coherence      9
# 1         2  Baseline  scene_block_1        Relevance      8
# 2         2  Baseline  scene_block_1  Interestingness      7
# 3         2  Baseline  scene_block_1            Humor      7
# 4         2  Baseline  scene_block_1  Overall Quality      8
# 5         2  Baseline  scene_block_2        Coherence      9
# 6         2  Baseline  scene_block_2        Relevance     10
# 7         2  Baseline  scene_block_2  Interestingness      8
# 8         2  Baseline  scene_block_2            Humor      8
# 9         2  Baseline  scene_block_2  Overall Quality      9
# 10        2  Baseline  scene_block_3        Coherence      9
# 11        2  Baseline  scene_block_3        Relevance     10
# 12        2  Baseline  scene_block_3  Interestingness      8
# 13        2  Baseline  scene_block_3            Humor      8
# 14        2  Baseline  scene_block_3  Overall Quality      9
# 15        2  Baseline  scene_block_4        Coherence      9
# 16        2  Baseline  scene_block_4        Relevance     10
# 17        2  Baseline  scene_block_4  Interestingness      8
# 18        2  Baseline  scene_block_4            Humor      7
# 19        2  Baseline  scene_block_4  Overall Quality      8
# 20        2  Baseline  scene_block_5        Coherence      9
# 21        2  Baseline  scene_block_5        Relevance     10
# 22        2  Baseline  scene_block_5  Interestingness      8
# 23        2  Baseline  scene_block_5            Humor      8
# 24        2  Baseline  scene_block_5  Overall Quality      9
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes support the episode concept and cha...
# 2   The scenes are engaging and narratively dynami...
# 3   The humor is character-driven and well-timed, ...
# 4   The structure, tone, and genre fit are all sol...
# 5   The scenes flow logically from one to the next...
# 6   Each scene supports the episode concept, chara...
# 7   The scenes are engaging and narratively dynami...
# 8   The comedy is well-timed and character-driven,...
# 9   The structure, tone, and genre fit are all str...
# 10  The scenes flow logically from one to the next...
# 11  The scenes are highly relevant to the episode ...
# 12  The scenes are engaging and narratively dynami...
# 13  The comedy is well-timed and character-driven,...
# 14  The scenes are well-structured and well-writte...
# 15  The scenes flow logically from one to the next...
# 16  The scenes are highly relevant to the episode'...
# 17  The scenes are engaging and narratively dynami...
# 18  The humor is character-driven and well-timed, ...
# 19  The scenes are well-structured, with a good ba...
# 20  The scenes flow logically from one to the next...
# 21  The scenes are highly relevant to the episode ...
# 22  The scenes are engaging and narratively dynami...
# 23  The comedy is well-timed and character-driven,...
# 24  The scenes are well-structured, maintain a con...

# %% [markdown]
# ### Episode 3

# %%
# Evaluate Baseline Episode 3 using scene descriptions and generated script blocks
baseline_evaluations_ep3 = evaluate_episode_blocks(
    client=client,
    episode_num=3,
    script_blocks=baseline_script_blocks[3],
    description_blocks=scene_description_blocks[3],
    episode_concept=episode_concept_3
)

# %%
# Access and print all scene block evaluations for Episode 3 (Baseline version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (Baseline) {'=' * 20}\n")
    print(baseline_evaluations_ep3[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The only minor issue is the sudden introduction of Earl, the parole officer, which could have been hinted at earlier for a smoother transition.
# - Relevance: 8 – The scenes support the episode concept and character arcs well, revealing Jimmy's past and his relationship with Earl. However, the estranged daughter, Sophie, mentioned in the concept is not present in these scenes, which is a significant omission.
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with the mystery of the giant key and Jimmy's past as a criminal lock-picker. However, the scenes could benefit from more conflict or tension to heighten the drama and interest.
# - Humor: 7 – The humor is character-driven and appropriately varied, with Jimmy's quirky interactions with his keys and Earl's unexpected interest in lock-picking. However, some of the jokes feel a bit forced and the laugh track is overused, which can detract from the comedy.
# - Overall Quality: 8 – The structure, tone, and genre fit are solid, and the writing is polished. The scenes effectively establish Jimmy's character and backstory, and introduce an intriguing mystery with the giant key. However, the humor could be improved and the estranged daughter should be incorporated to fully align with the episode concept.
#
# ==================== Scene Block 2 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The introduction of Sophie is a surprise, but it's handled in a way that doesn't disrupt the overall flow of the story. The only minor issue is the sudden introduction of a poker game, which feels a bit forced.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. The introduction of Sophie adds a new layer to Jimmy's character and the mysterious package from his past. Earl's role as a parole officer and friend also continues to be explored.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with the introduction of Sophie adding a new twist to the story. However, the scenes could benefit from a bit more originality, as the estranged child showing up unexpectedly is a fairly common sitcom trope.
#
# - Humor: 7 – The humor is character-driven and appropriately varied, with a mix of situational comedy, wordplay, and character quirks. However, the laugh track feels a bit overused, and some of the jokes are predictable.
#
# - Overall Quality: 8 – The structure, tone, and genre fit are all solid, and the writing is polished. The scenes successfully balance humor with more serious character development. However, the humor could be more innovative, and the introduction of the poker game feels a bit out of place.
#
# ==================== Scene Block 3 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and reactions are believable and consistent with their established personalities. The only minor issue is the sudden introduction of Earl's cat, which feels a bit abrupt.
#
# - Relevance: 8 – The scenes support the episode concept and character arcs well. Jimmy's relationship with his daughter Sophie is developed further, and Earl's personal life is introduced, adding depth to his character. However, the mysterious package from Jimmy's past mentioned in the episode concept is not addressed in these scenes.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of humor, character development, and plot progression. The introduction of Earl's cat adds an unexpected twist. However, the scenes could benefit from a bit more conflict or tension to heighten the stakes.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of humorous situations and dialogue. The laugh track might feel a bit overused to some viewers, but it fits the traditional sitcom format.
#
# - Overall Quality: 8 – The scenes are well-structured, with a good balance of humor and heart. The tone is consistent with the sitcom genre, and the writing is polished. However, the scenes could be improved by addressing the mysterious package from Jimmy's past and adding more conflict or tension.
#
# ==================== Scene Block 4 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The dialogue is clear and the actions of the characters make sense within the context of the story. The only minor issue is the sudden appearance of the mysterious package in Scene 14, which could have been foreshadowed in earlier scenes for better coherence.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept and prior developments. They continue the narrative of Jimmy teaching Sophie about locksmithing, while also introducing a new element of mystery with the package and the Second Lock. The scenes also further develop the characters' relationships and personal arcs, particularly Jimmy's relationship with Sophie and his acceptance of his current life situation.
#
# - Interestingness: 8 – The scenes are engaging and introduce a new narrative element with the Second Lock, which adds intrigue and potential for future plot developments. The emotional conversation between Jimmy and Sophie in Scene 13 also adds depth to their relationship. However, the scenes could benefit from more unexpected twists or conflicts to increase the narrative tension.
#
# - Humor: 7 – The humor in these scenes is character-driven and well-timed, with a good mix of verbal and situational comedy. The laugh track might seem a bit overused, but it fits the sitcom genre. The humor could be more varied and punchy, with more comedic misunderstandings or wordplay.
#
# - Overall Quality: 8 – The scenes are well-structured and maintain a consistent tone that fits the sitcom genre. The dialogue is natural and the characters are well-developed. The introduction of the Second Lock adds an interesting element to the story. However, the writing could be more polished, with sharper humor and more dynamic narrative developments.
#
# ==================== Scene Block 5 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and dialogue are consistent with their established personalities and the situation they're in. The only minor issue is the repetition of certain elements, such as the laughter and the jingle of keys, which could be varied more for better pacing.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They build on the established relationships between Jimmy, Sophie, and Earl, and further explore the mystery of the Second Lock and the antique key. They also set up potential future storylines, such as Sophie's decision to stay and the adventures they might find.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of humor, character development, and plot progression. However, they could be more original, as they rely heavily on familiar sitcom tropes, such as the surprise revelation and the humorous misunderstanding.
#
# - Humor: 7 – The comedy is well-timed and character-driven, with a good variety of jokes and humorous situations. However, the humor could be more varied and sophisticated, as it relies heavily on laugh tracks and simple punchlines.
#
# - Overall Quality: 8 – The scenes are well-structured, with a consistent tone and a good fit for the sitcom genre. The writing is polished, with clear and engaging dialogue. However, the scenes could benefit from more originality and sophistication in the humor, as well as more varied pacing and scene elements.

# %%
# Extract scores into a DataFrame for Baseline Episode 3
baseline_scores_ep3_df = extract_evaluation_scores(
    baseline_evaluations_ep3,
    episode_number=3,
    version_label="Baseline"
)

display(baseline_scores_ep3_df)
# Out:
#     episode   version    scene_block        criterion  score  \
# 0         3  Baseline  scene_block_1        Coherence      9
# 1         3  Baseline  scene_block_1        Relevance      8
# 2         3  Baseline  scene_block_1  Interestingness      8
# 3         3  Baseline  scene_block_1            Humor      7
# 4         3  Baseline  scene_block_1  Overall Quality      8
# 5         3  Baseline  scene_block_2        Coherence      9
# 6         3  Baseline  scene_block_2        Relevance     10
# 7         3  Baseline  scene_block_2  Interestingness      8
# 8         3  Baseline  scene_block_2            Humor      7
# 9         3  Baseline  scene_block_2  Overall Quality      8
# 10        3  Baseline  scene_block_3        Coherence      9
# 11        3  Baseline  scene_block_3        Relevance      8
# 12        3  Baseline  scene_block_3  Interestingness      8
# 13        3  Baseline  scene_block_3            Humor      8
# 14        3  Baseline  scene_block_3  Overall Quality      8
# 15        3  Baseline  scene_block_4        Coherence      9
# 16        3  Baseline  scene_block_4        Relevance     10
# 17        3  Baseline  scene_block_4  Interestingness      8
# 18        3  Baseline  scene_block_4            Humor      7
# 19        3  Baseline  scene_block_4  Overall Quality      8
# 20        3  Baseline  scene_block_5        Coherence      9
# 21        3  Baseline  scene_block_5        Relevance     10
# 22        3  Baseline  scene_block_5  Interestingness      8
# 23        3  Baseline  scene_block_5            Humor      7
# 24        3  Baseline  scene_block_5  Overall Quality      8
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes support the episode concept and cha...
# 2   The scenes are engaging and narratively dynami...
# 3   The humor is character-driven and appropriatel...
# 4   The structure, tone, and genre fit are solid, ...
# 5   The scenes flow logically from one to the next...
# 6   The scenes are highly relevant to the episode ...
# 7   The scenes are engaging and narratively dynami...
# 8   The humor is character-driven and appropriatel...
# 9   The structure, tone, and genre fit are all sol...
# 10  The scenes flow logically from one to the next...
# 11  The scenes support the episode concept and cha...
# 12  The scenes are engaging and narratively dynami...
# 13  The comedy is well-timed and character-driven,...
# 14  The scenes are well-structured, with a good ba...
# 15  The scenes flow logically from one to the next...
# 16  The scenes are highly relevant to the episode ...
# 17  The scenes are engaging and introduce a new na...
# 18  The humor in these scenes is character-driven ...
# 19  The scenes are well-structured and maintain a ...
# 20  The scenes flow logically from one to the next...
# 21  The scenes are highly relevant to the episode ...
# 22  The scenes are engaging and narratively dynami...
# 23  The comedy is well-timed and character-driven,...
# 24  The scenes are well-structured, with a consist...

# %% [markdown]
# ### Episode 4

# %%
# Evaluate Baseline Episode 4 using scene descriptions and generated script blocks
baseline_evaluations_ep4 = evaluate_episode_blocks(
    client=client,
    episode_num=4,
    script_blocks=baseline_script_blocks[4],
    description_blocks=scene_description_blocks[4],
    episode_concept=episode_concept_4
)

# %%
# Access and print all scene block evaluations for Episode 4 (Baseline version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (Baseline) {'=' * 20}\n")
    print(baseline_evaluations_ep4[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and dialogue are consistent with their established personalities and the situation they're in. The only minor issue is the repetition of the key drop, which could be seen as a bit redundant.
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They establish the main characters, their relationships, and the setting effectively. They also set up the main conflict of the episode: Samantha's decision to drop out of business school and join her father's locksmith shop.
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of character development, conflict, and humor. However, they could benefit from a bit more originality, as the "business school dropout" and "ex-con starting a new life" tropes are fairly common.
# - Humor: 7 – The comedy is well-timed and character-driven, with a good variety of jokes. However, some of the humor relies heavily on the laugh track and could be improved with more clever or unexpected punchlines.
# - Overall Quality: 8 – The structure, tone, and genre fit are all solid, and the writing is polished. The scenes effectively set up the premise of the sitcom and introduce the main characters and their relationships. However, the humor and originality could be improved to make the scenes more engaging and memorable.
#
# ==================== Scene Block 2 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically and maintain internal consistency. The dialogue and actions of the characters are in line with their established personalities and the situation they are in. The only minor issue is the sudden introduction of the idea of an apprentice, which seems a bit abrupt.
#
# - Relevance: 10 – The scenes support the episode concept, character arcs, and prior developments perfectly. The scenes show the growing bond between Jimmy and Samantha, their struggles and successes in running the locksmith shop, and the recurring humor from Terry's visits.
#
# - Interestingness: 8 – The scenes are original and engaging, with a good mix of humor, character development, and plot progression. However, the narrative could be more dynamic with the introduction of more unexpected elements or conflicts.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of humor from the characters' interactions, Samantha's struggles with the lock, and Terry's eccentricity. However, some of the jokes are a bit predictable and could be more creative.
#
# - Overall Quality: 9 – The structure, tone, and genre fit are excellent, and the writing is polished. The scenes effectively balance humor, character development, and plot progression. The only minor issue is the need for more unexpected elements or conflicts to make the narrative more dynamic.
#
# ==================== Scene Block 3 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining internal consistency. The dialogue and actions of the characters are consistent with their established personalities and the situation they are in. The only minor issue is the sudden decision to hire an apprentice, which could have been foreshadowed earlier.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They continue to explore the dynamic between Jimmy and Samantha, their struggles in running the locksmith shop, and their interactions with Terry. The decision to hire an apprentice also introduces a new plot point that can be developed in future episodes.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of comedic and heartfelt moments. The introduction of the apprentice hiring plot adds a new layer of interest. However, the scenes could benefit from a bit more originality, as some of the comedic beats feel somewhat predictable.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of jokes and humorous situations. The humor is derived from the characters' personalities and the situations they find themselves in, which makes it feel natural and authentic. However, some of the jokes are a bit on the nose and could be more subtle.
#
# - Overall Quality: 9 – The scenes are well-structured, with a good balance of comedy and character development. The tone is consistent with the sitcom genre, and the writing is polished and professional. The scenes effectively advance the plot and deepen the characters, making for an engaging and entertaining viewing experience.
#
# ==================== Scene Block 4 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The only minor issue is the sudden influx of customers in Scene 16, which could have been foreshadowed in previous scenes for better continuity.
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They show Samantha's growing confidence and competence in the locksmith business, Jimmy's pride in his daughter, and the introduction of Eddie, a new character who fits into the theme of second chances.
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of comedy, character development, and plot progression. However, they could be more original, as they follow a fairly predictable sitcom formula.
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of jokes, from situational humor to character-based teasing. However, some of the laugh track placements feel a bit forced and could be better integrated into the dialogue.
# - Overall Quality: 9 – The structure, tone, and genre fit are all excellent, and the writing is polished and professional. The scenes effectively balance comedy with heartfelt moments, and they advance the plot while developing the characters. The only minor issues are the somewhat predictable plot and the occasional forced laugh track.
#
# ==================== Scene Block 5 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The dialogue and actions of the characters are consistent with their established personalities and relationships. The only minor issue is the sudden introduction of Eddie, who is not mentioned in the core concept or previous scenes.
# - Relevance: 9 – The scenes support the episode concept, character arcs, and prior developments. They build on the established relationships between Jimmy, Samantha, and Terry, and introduce a new character, Eddie, into the mix. The scenes also continue the theme of the locksmith shop as a place of work, family, and second chances.
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a mix of humor, sentimentality, and character development. However, they are not particularly original, following a fairly standard sitcom structure and relying on familiar tropes (e.g., the photo album, the wise older character, the nervous newcomer).
# - Humor: 8 – The comedy is well-timed and character-driven, with a good mix of verbal humor, physical comedy, and situational humor. However, the humor is somewhat predictable and relies heavily on a laugh track, which may not appeal to all viewers.
# - Overall Quality: 8.5 – The scenes are well-structured, with a consistent tone and a good fit for the sitcom genre. The writing is polished, with clear, concise dialogue and effective use of stage directions. However, the scenes could benefit from more originality and subtlety in the humor.

# %%
# Extract scores into a DataFrame for Baseline Episode 5
baseline_scores_ep4_df = extract_evaluation_scores(
    baseline_evaluations_ep4,
    episode_number=4,
    version_label="Baseline"
)

display(baseline_scores_ep4_df)
# Out:
# ⚠️ Skipped unmatched line in scene_block_5: - Overall Quality: 8.5 – The scenes are well-structured, with a consistent tone and a good fit for the sitcom genre. The writing is polished, with clear, concise dialogue and effective use of stage directions. However, the scenes could benefit from more originality and subtlety in the humor.
#     episode   version    scene_block        criterion  score  \
# 0         4  Baseline  scene_block_1        Coherence      9
# 1         4  Baseline  scene_block_1        Relevance     10
# 2         4  Baseline  scene_block_1  Interestingness      8
# 3         4  Baseline  scene_block_1            Humor      7
# 4         4  Baseline  scene_block_1  Overall Quality      8
# 5         4  Baseline  scene_block_2        Coherence      9
# 6         4  Baseline  scene_block_2        Relevance     10
# 7         4  Baseline  scene_block_2  Interestingness      8
# 8         4  Baseline  scene_block_2            Humor      8
# 9         4  Baseline  scene_block_2  Overall Quality      9
# 10        4  Baseline  scene_block_3        Coherence      9
# 11        4  Baseline  scene_block_3        Relevance     10
# 12        4  Baseline  scene_block_3  Interestingness      8
# 13        4  Baseline  scene_block_3            Humor      8
# 14        4  Baseline  scene_block_3  Overall Quality      9
# 15        4  Baseline  scene_block_4        Coherence      9
# 16        4  Baseline  scene_block_4        Relevance     10
# 17        4  Baseline  scene_block_4  Interestingness      8
# 18        4  Baseline  scene_block_4            Humor      8
# 19        4  Baseline  scene_block_4  Overall Quality      9
# 20        4  Baseline  scene_block_5        Coherence      9
# 21        4  Baseline  scene_block_5        Relevance      9
# 22        4  Baseline  scene_block_5  Interestingness      8
# 23        4  Baseline  scene_block_5            Humor      8
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes are highly relevant to the episode ...
# 2   The scenes are engaging and narratively dynami...
# 3   The comedy is well-timed and character-driven,...
# 4   The structure, tone, and genre fit are all sol...
# 5   The scenes flow logically and maintain interna...
# 6   The scenes support the episode concept, charac...
# 7   The scenes are original and engaging, with a g...
# 8   The comedy is well-timed and character-driven,...
# 9   The structure, tone, and genre fit are excelle...
# 10  The scenes flow logically from one to the next...
# 11  The scenes are highly relevant to the episode ...
# 12  The scenes are engaging and narratively dynami...
# 13  The comedy is well-timed and character-driven,...
# 14  The scenes are well-structured, with a good ba...
# 15  The scenes flow logically from one to the next...
# 16  The scenes are highly relevant to the episode ...
# 17  The scenes are engaging and narratively dynami...
# 18  The comedy is well-timed and character-driven,...
# 19  The structure, tone, and genre fit are all exc...
# 20  The scenes flow logically from one to the next...
# 21  The scenes support the episode concept, charac...
# 22  The scenes are engaging and narratively dynami...
# 23  The comedy is well-timed and character-driven,...

# %% [markdown]
# ### Episode 5

# %%
# Evaluate Baseline Episode 5 using scene descriptions and generated script blocks
baseline_evaluations_ep5 = evaluate_episode_blocks(
    client=client,
    episode_num=5,
    script_blocks=baseline_script_blocks[5],
    description_blocks=scene_description_blocks[5],
    episode_concept=episode_concept_5
)

# %%
# Access and print all scene block evaluations for Episode 5 (Baseline version)
for i in range(1, 6):
    print(f"\n{'=' * 20} Scene Block {i} Evaluation (Baseline) {'=' * 20}\n")
    print(baseline_evaluations_ep5[f"scene_block_{i}"])
# Out:
# ==================== Scene Block 1 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. Frankie's journey from prison to his new life as a locksmith is clear and easy to follow. The only minor issue is the sudden appearance of Len, the parole officer, which could have been foreshadowed for smoother transition.
#
# - Relevance: 8 – The scenes support the episode concept and character arcs well. We see Frankie's transition from prison to freedom, his introduction to his new life as a locksmith, and his first interactions with his parole officer. However, the estranged daughter, Ellie, is not introduced or mentioned in these scenes, which is a missed opportunity for character development.
#
# - Interestingness: 7 – The scenes are engaging and narratively dynamic, with Frankie's journey from prison to locksmith shop providing a compelling story. However, the scenes could benefit from more originality and unexpected twists to keep the audience guessing.
#
# - Humor: 7 – The humor is character-driven and well-timed, with Frankie's sarcastic remarks and reactions to his new life providing most of the laughs. However, the humor could be more varied, as it currently relies heavily on Frankie's one-liners and laugh tracks.
#
# - Overall Quality: 8 – The structure is solid, the tone is consistent, and the writing is polished. The scenes fit well within the sitcom genre, with a good balance of humor and character development. However, the scenes could benefit from more originality and unexpected twists, as well as the introduction of key characters like Ellie.
#
# ==================== Scene Block 2 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining internal consistency. Frankie's journey from being overwhelmed by his new locksmith shop to slowly gaining confidence and even teaching his daughter is well-structured and coherent.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They show Frankie's struggle and growth in his new role as a locksmith, his interactions with his quirky parole officer, and his reconnection with his estranged daughter.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of humor, character development, and emotional moments. However, the setting remains the same throughout all scenes, which might limit the variety of situations and interactions.
#
# - Humor: 7 – The humor is character-driven and well-timed, with a good mix of situational comedy, witty dialogue, and physical humor. However, some of the jokes might be a bit predictable and the laugh track could be seen as intrusive.
#
# - Overall Quality: 8 – The scenes are well-structured, the tone is consistent, and the writing is polished. The character dynamics are interesting and the humor is well-integrated. However, the scenes could benefit from a bit more variety in terms of setting and situation to keep the audience engaged.
#
# ==================== Scene Block 3 Evaluation (Baseline) ====================
#
# - Coherence: 8 – The scenes flow logically from one to the next, maintaining a consistent narrative. However, there is some repetition in the dialogue and situations (e.g., Ellie struggling with the lock) that slightly disrupts the coherence.
# - Relevance: 9 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They continue to explore Frankie's new life as a locksmith, his relationship with Ellie, and the dynamic with Len.
# - Interestingness: 7 – While the scenes are engaging and provide character development, there is a lack of narrative dynamism. The scenes are largely confined to the locksmith shop and revolve around similar situations (Ellie struggling with locks). More variety in settings or situations could enhance the interest level.
# - Humor: 8 – The humor is well-timed and character-driven, with a good mix of situational comedy and witty dialogue. However, some of the jokes are repetitive, which reduces their impact.
# - Overall Quality: 8 – The structure, tone, and genre fit are solid, and the writing is polished. However, the scenes could benefit from more variety in settings and situations, as well as more diverse humor.
#
# ==================== Scene Block 4 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and dialogue are consistent with their established personalities and the situation they're in. The only minor issue is the repeated use of the cat causing chaos, which could be varied a bit more for better coherence.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They continue the narrative of Frankie teaching Ellie the locksmith trade and their growing bond, while also incorporating Len's philosophical approach and the chaos of their new life together.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a good mix of character interaction, humor, and plot development. However, the concept of a former convict teaching his daughter the locksmith trade isn't particularly original, and the scenes could benefit from a bit more unexpected twists or unique elements.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good variety of jokes, physical humor, and situational comedy. However, some of the humor relies heavily on the laugh track and could be more subtle or clever.
#
# - Overall Quality: 9 – The scenes are well-structured and fit the sitcom genre well. The tone is consistent and the writing is polished. The characters are likable and their interactions are entertaining. The only minor issues are the somewhat predictable humor and the need for a bit more originality in the concept or plot twists.
#
# ==================== Scene Block 5 Evaluation (Baseline) ====================
#
# - Coherence: 9 – The scenes flow logically from one to the next, maintaining a consistent narrative. The characters' actions and dialogue are consistent with their established personalities and the situation they are in. The only minor issue is the sudden introduction of the cat character, which could have been introduced earlier for better coherence.
#
# - Relevance: 10 – The scenes are highly relevant to the episode concept, character arcs, and prior developments. They show Frankie, Ellie, and Len working together to improve the shop, which ties into the themes of second chances and potential. The scenes also further develop the relationships between the characters, particularly between Frankie and Ellie.
#
# - Interestingness: 8 – The scenes are engaging and narratively dynamic, with a mix of comedic and heartfelt moments. The idea of cleaning and renovating the shop as a metaphor for Frankie's second chance is original and interesting. However, the scenes could benefit from a bit more conflict or unexpected developments to increase the narrative tension.
#
# - Humor: 8 – The comedy is well-timed and character-driven, with a good mix of verbal humor, physical comedy, and situational humor. The humor is also appropriately varied, with a balance of teasing, self-deprecating jokes, and comedic misunderstandings. However, some of the jokes are a bit predictable and could be more original.
#
# - Overall Quality: 9 – The scenes are well-structured, with a clear narrative arc and a satisfying conclusion. The tone is consistent with the sitcom genre, and the writing is polished and professional. The scenes effectively balance comedy with character development and thematic exploration. However, there is room for improvement in terms of originality and narrative tension.

# %%
# Extract scores into a DataFrame for Baseline Episode 5
baseline_scores_ep5_df = extract_evaluation_scores(
    baseline_evaluations_ep5,
    episode_number=5,
    version_label="Baseline"
)

display(baseline_scores_ep5_df)
# Out:
#     episode   version    scene_block        criterion  score  \
# 0         5  Baseline  scene_block_1        Coherence      9
# 1         5  Baseline  scene_block_1        Relevance      8
# 2         5  Baseline  scene_block_1  Interestingness      7
# 3         5  Baseline  scene_block_1            Humor      7
# 4         5  Baseline  scene_block_1  Overall Quality      8
# 5         5  Baseline  scene_block_2        Coherence      9
# 6         5  Baseline  scene_block_2        Relevance     10
# 7         5  Baseline  scene_block_2  Interestingness      8
# 8         5  Baseline  scene_block_2            Humor      7
# 9         5  Baseline  scene_block_2  Overall Quality      8
# 10        5  Baseline  scene_block_3        Coherence      8
# 11        5  Baseline  scene_block_3        Relevance      9
# 12        5  Baseline  scene_block_3  Interestingness      7
# 13        5  Baseline  scene_block_3            Humor      8
# 14        5  Baseline  scene_block_3  Overall Quality      8
# 15        5  Baseline  scene_block_4        Coherence      9
# 16        5  Baseline  scene_block_4        Relevance     10
# 17        5  Baseline  scene_block_4  Interestingness      8
# 18        5  Baseline  scene_block_4            Humor      8
# 19        5  Baseline  scene_block_4  Overall Quality      9
# 20        5  Baseline  scene_block_5        Coherence      9
# 21        5  Baseline  scene_block_5        Relevance     10
# 22        5  Baseline  scene_block_5  Interestingness      8
# 23        5  Baseline  scene_block_5            Humor      8
# 24        5  Baseline  scene_block_5  Overall Quality      9
#
#                                         justification
# 0   The scenes flow logically from one to the next...
# 1   The scenes support the episode concept and cha...
# 2   The scenes are engaging and narratively dynami...
# 3   The humor is character-driven and well-timed, ...
# 4   The structure is solid, the tone is consistent...
# 5   The scenes flow logically from one to the next...
# 6   The scenes are highly relevant to the episode ...
# 7   The scenes are engaging and narratively dynami...
# 8   The humor is character-driven and well-timed, ...
# 9   The scenes are well-structured, the tone is co...
# 10  The scenes flow logically from one to the next...
# 11  The scenes are highly relevant to the episode ...
# 12  While the scenes are engaging and provide char...
# 13  The humor is well-timed and character-driven, ...
# 14  The structure, tone, and genre fit are solid, ...
# 15  The scenes flow logically from one to the next...
# 16  The scenes are highly relevant to the episode ...
# 17  The scenes are engaging and narratively dynami...
# 18  The comedy is well-timed and character-driven,...
# 19  The scenes are well-structured and fit the sit...
# 20  The scenes flow logically from one to the next...
# 21  The scenes are highly relevant to the episode ...
# 22  The scenes are engaging and narratively dynami...
# 23  The comedy is well-timed and character-driven,...
# 24  The scenes are well-structured, with a clear n...

# %% [markdown]
# ## Average Scores
#
# Below, we calculate the average evaluation score for each criterion across all five episodes. We group by evaluation type (ReAct vs. Baseline) and compare how each version performed on coherence, relevance, interestingness, humor, and overall quality. This summary table provides a high-level view of performance differences across the two script-generation strategies.

# %%
# Combine all ReAct episode score DataFrames
react_all_df = pd.concat([
    react_scores_ep1_df,
    react_scores_ep2_df,
    react_scores_ep3_df,
    react_scores_ep4_df,
    react_scores_ep5_df
], ignore_index=True)

# Combine all Baseline episode score DataFrames
baseline_all_df = pd.concat([
    baseline_scores_ep1_df,
    baseline_scores_ep2_df,
    baseline_scores_ep3_df,
    baseline_scores_ep4_df,
    baseline_scores_ep5_df
], ignore_index=True)

# Combine both into a single full evaluation DataFrame
full_eval_df = pd.concat([react_all_df, baseline_all_df], ignore_index=True)

# Group by version and criterion, then compute average score
average_scores_df = (
    full_eval_df
    .groupby(["version", "criterion"])["score"]
    .mean()
    .round(2)
    .reset_index()
    .pivot(index="criterion", columns="version", values="score")
    .reset_index()
)

# Display the final comparison table
display(average_scores_df)
# Out:
# version        criterion  Baseline  ReAct
# 0              Coherence      8.96   7.76
# 1                  Humor      7.68   7.92
# 2        Interestingness      7.88   7.56
# 3        Overall Quality      8.46   7.88
# 4              Relevance      9.60   8.28
